# %% [markdown]
# # Requirements

# %% [markdown]
# - Ensure the *_WC_2022_final.csv* is available on your environment python Environment
# - Ensure you have installed the following libraries:
#     - pandas:  !pip install pandas
#     - mlp: !pip install mplsoccer (*Downloading mplsoccer-1.2.1-py3-none-any.whl (78 kB)*)

# %%
# !pip install mplsoccer

# %%
# !pip install pandas

# %% [markdown]
# # Info

# %%
group_number = ''

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

from mplsoccer import Pitch

# %% [markdown]
# # Import Data
# Read the *_WC_2022_final.csv* file
#
#
# Hint: pd.read_csv()

# %% [markdown]
# # Task 1:

# %% [markdown]
# ## [2pt] Find the Players with the highest number of passes between minutes 45 and 90

# %% [markdown]
# Enter here the Name of the Player with the highest number of passess between minutes 45 and 90.

# %%
playerName_MostPasses = ''

# %% [markdown]
# Enter here the Number of Passes of the player with the highest number of passess between minutes 45 and 90.

# %%
passCount_MostPasses = 0

# %% [markdown]
# ## [1pt] Find the Team with the highest number of passes between minutes 45 and 90

# %% [markdown]
# Enter the Name of the Team with the highest total number of passes between minutes 45 and 90.

# %%
teamName_MostTotPasses = ''

# %% [markdown]
# Enter here the total Number of Passes of the Team with the highest total number of passes between minutes 45 and 90.

# %%
teamTotPassCount_MostTotPasses = 0

# %% [markdown]
# # Task 2

# %% [markdown]
# ## [2pt] Successful Pass: Find the Player with the highest number of Successful passes between minutes 45 and 90

# %% [markdown]
# Enter here the Name of the Player with the highest number of **Successful** passess between minutes 45 and 90.

# %%
playerName_MostSuccessfulPass = ''

# %% [markdown]
# Enter here the Number of Passes of the player with the highest number of **Successful** passess between minutes 45 and 90.

# %%
passCount_MostSuccessfulPass = 0

# %% [markdown]
# # Task 3

# %% [markdown]
# ## [2pt] Shot:  Find the Player with the highest number of Shots between minutes 45 and 90 of the match

# %% [markdown]
# Enter here the Name of the Player with the highest number of Shots between minutes 45 and 90.

# %%
playerName_MostShots = ''

# %% [markdown]
# Enter here the Number of Shots of the player with the highest number of Shots between minutes 45 and 90.

# %%
shotsCount_MostShots = 0

# %% [markdown]
# ## [3pt] Select the shot with the highest XG that it is not a Penalty between minutes 45 and 90
# Location Needed

# %% [markdown]
# Enter here the Name of the Player with the highest Exepected Goal Value between minutes 45 and 90.
# The shot must not be a penalty.

# %%
playerName_topXG= ''

# %% [markdown]
# Enter here the Value of Expected Goal (XG) of the Player with the highest Exepected Goal Value between minutes 45 and 90.
# The shot must not be a penalty.

# %%
value_topXG = 0

# %% [markdown]
# Enter here the Location of the Shot with the Highest Expected Goal (XG) between minutes 45 and 90.
# The shot must not be a penalty.

# %%
shot_location_topXG= [0, 0]

# %%
from mplsoccer import Pitch

# %% [markdown]
# # Task 4

# %% [markdown]
# ## [5pt] Print position of the players with the highest XG in the rantge of time selected
# To complete this task you must provide the list of the position of the players in the pitch
# - Print Pitch
# - TeamMate color = 'red'
# - OppositePlayers color = 'blue'
# - Player who shot color = 'green'

# %%
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(10,8))



'''

.


.



.



'''
# Out:
# '\n\n.\n\n\n.\n\n\n\n.\n\n\n\n'

# %% [markdown]
# Enter here the List of the Postion of the teammates of the Player who is shooting the shot with the Highest Exepected Goal (XG) Value between minutes 45 and 90.
# The shot must not be a penalty.

# %%
teammates_XG_location_list = [[0,0], [0,0], ...]

# %% [markdown]
# Enter here the List of the Postion of the opponents of the Player who is shooting the shot with the Highest Exepected Goal (XG) Value between minutes 45 and 90.
# The shot must not be a penalty.

# %%
opponents_XG_location_list = [[0,0], [0,0], ...]

# %% [markdown]
# # Scoring Calculation

# %%
dict_score = {
            'group': group_number,
            'playerName_MostPasses':playerName_MostPasses,
            'passCount_MostPasses':passCount_MostPasses,
            'teamName_MostTotPasses': teamName_MostTotPasses ,
            'teamTotPassCount_MostTotPasses': teamTotPassCount_MostTotPasses ,
            'playerName_MostSuccessfulPass': playerName_MostSuccessfulPass,
            'passCount_MostSuccessfulPass':passCount_MostSuccessfulPass,
            'playerName_MostShots': playerName_MostShots,
            'shotsCount_MostShots':shotsCount_MostShots,
            'playerName_topXG':playerName_topXG,
            'value_topXG': value_topXG,
            'shot_location_topXG': str(shot_location_topXG),
            'teammates_XG_location_list':str(teammates_XG_location_list),
            'opponents_XG_location_list':str(opponents_XG_location_list),
            }

# %%
df_out = pd.DataFrame.from_dict(dict_score, orient='index', columns=['value'])
df_out

# %%
path_to_save_output = ''

df_out.to_csv(f'{path_to_save_output}/GNB_SportAnalytics_{group_number}.csv')

# %% [markdown]
# # Upload
#
# Once your files has been created please upload it using this form:
# https://docs.google.com/forms/d/e/1FAIpQLSdwnYgUwkKzubgMfTjOY8YWeDy86S47n-E6Uz5pq1FlMsuJDA/viewform
#
# Two files are expected to be uploaded:
#
#
# *   GNB_SportAnalytics_{group_number}.csv
# *   {your_presentation}: based on the shared template 2023_GNB_School_SportsAnalytics_template.pptx in **.pdf format**
